# %%
#nombre de ligne dans df

#len(df) ou len(df.index) , df.isnull() , df.column.isnull()

import numpy is np
import pandas as pd

sales_data = df.isnull()
sales_data.sales.isnull()



# df.replace()

df2 = df.replace(0, 5) #remplacer 0 avec 5

# 
# df['colname'].str

# %%
import pandas as pd

filename = 'C:/Users/6176093/Desktop/data/nyc-parking-violations-2020.csv'

df = pd.read_csv(filename, usecols = ['Plate ID', 'Registration State', 'Vehicle Make', 'Violation Time', 'Street Name', 'Vehicle Color'])
df.head()
# Out:
#   Plate ID Registration State Vehicle Make Violation Time      Street Name  \
# 0   J58JKX                 NJ        HONDA          0523P            43 ST
# 1  KRE6058                 PA        ME/BE          0428P         UNION ST
# 2  444326R                 NJ        LEXUS          0625A  CLERMONT AVENUE
# 3  F728330                 OH        CHEVR          1106A     DIVISION AVE
# 4  FMY9090                 NY         JEEP          1253A         GRAND ST
#
#   Vehicle Color
# 0            BK
# 1           BLK
# 2         BLACK
# 3           NaN
# 4          GREY

# %%
len(df)
# Out:
# 12495734

# %%
pd.isnull(df)
# Out:
#           Plate ID  Registration State  Vehicle Make  Violation Time  \
# 0            False               False         False           False
# 1            False               False         False           False
# 2            False               False         False           False
# 3            False               False         False           False
# 4            False               False         False           False
# ...            ...                 ...           ...             ...
# 12495729     False               False         False           False
# 12495730     False               False         False           False
# 12495731     False               False         False           False
# 12495732     False               False         False           False
# 12495733     False               False         False           False
#
#           Street Name  Vehicle Color
# 0               False          False
# 1               False          False
# ...

# %%
df.shape
# Out:
# (12495734, 6)

# %%
df.dropna()
# Out:
#           Plate ID Registration State Vehicle Make Violation Time  \
# 0           J58JKX                 NJ        HONDA          0523P
# 1          KRE6058                 PA        ME/BE          0428P
# 2          444326R                 NJ        LEXUS          0625A
# 4          FMY9090                 NY         JEEP          1253A
# 5          KDG0693                 PA         HYUN          0525P
# ...            ...                ...          ...            ...
# 12495729   62161MM                 NY         FORD          1111A
# 12495730   GYE7330                 NY        HONDA          0444P
# 12495731   HNY4802                 NY         FORD          0210A
# 12495732  T687081C                 NY        TOYOT          0225P
# 12495733    3497ZN                 WA        UTILI          0456A
#
#                Street Name Vehicle Color
# 0                    43 ST            BK
# 1                 UNION ST           BLK
# 2          CLERMONT AVENUE         BLACK
# ...

# %%
pd.isnull(df)
# Out:
#           Plate ID  Registration State  Vehicle Make  Violation Time  \
# 0            False               False         False           False
# 1            False               False         False           False
# 2            False               False         False           False
# 3            False               False         False           False
# 4            False               False         False           False
# ...            ...                 ...           ...             ...
# 12495729     False               False         False           False
# 12495730     False               False         False           False
# 12495731     False               False         False           False
# 12495732     False               False         False           False
# 12495733     False               False         False           False
#
#           Street Name  Vehicle Color
# 0               False          False
# 1               False          False
# ...

# %%
df2 = df.dropna()

# %%
len(df2)
# Out:
# 12048375

# %%
pd.isnull(df2)
# Out:
#           Plate ID  Registration State  Vehicle Make  Violation Time  \
# 0            False               False         False           False
# 1            False               False         False           False
# 2            False               False         False           False
# 4            False               False         False           False
# 5            False               False         False           False
# ...            ...                 ...           ...             ...
# 12495729     False               False         False           False
# 12495730     False               False         False           False
# 12495731     False               False         False           False
# 12495732     False               False         False           False
# 12495733     False               False         False           False
#
#           Street Name  Vehicle Color
# 0               False          False
# 1               False          False
# ...

# %%
df3 = len(df) - len(df2)
df3
# Out:
# 447359

# %%
df4 = len(df) - df3
df4
# Out:
# 12048375

# %%
df5 = df4 * 100
df5
# Out:
# 1204837500

# %%
df6 = df.dropna(subset = ['Plate ID', 'Registration State', 'Vehicle Make', 'Street Name'] )
len(df6)
# Out:
# 12431949
